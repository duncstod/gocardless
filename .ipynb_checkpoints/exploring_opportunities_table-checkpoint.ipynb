# %% [markdown]
# # Data exploration
#
#
# ## Objective
#
# - Create a table with a row per opportunity, an outcome variable and a set of features
#
# 1) Features can be opportunity / account attributes
#
# 2) A history of interactions between GC and the opportunity
#
# ----

# %% [markdown]
# ## Set up env

# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.float_format = '{:,.3f}'.format
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # default='warn'

import matplotlib.colors as colors
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')
# %config InlineBackend.figure_format = 'retina'
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Read in data

# %%
opportunities_df = pd.read_csv("data/opportunities_lg.csv")
# Out:
# /usr/local/anaconda3/envs/gocardless_eda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (6,41,42,45,88,91,111,112,121,122,161,163,165,166,174,179,185,186,189,201,202,203,217,218,219,220,221,222,223,224,225,226,228,229,230,231,232,233,237) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Inspect

# %%
opportunities_df.shape
# Out:
# (20810, 241)

# %%
opportunities_df.head()
# Out:
#        opportunity_id opportunity_owner_id          account_id  \
# 0  006b000000Cu7ucAAB   0050X00000608b0QAA  001b000000nSVI2AAO
# 1  006b000000NIKhzAAH   0050X0000060K51QAE  0010X00004DgtCJQAZ
# 2  006b000000JHWQVAA5   0050X0000076P3VQAU  001b000003M17SAAAZ
# 3  006b000000NIwo2AAD   0050X000007soS7QAI  001b000003ai0LGAAY
# 4  006b000000JIdwdAAD   0050X000007soS7QAI  001b000003NPIzEAAX
#
#     parent_account_id previous_opportunity_id salesforce_organisation_id  \
# 0  001b000000nSVI2AAO                     NaN                        NaN
# 1  0010X00004DgtCJQAZ                     NaN                        NaN
# 2  001b000003M17SAAAZ                     NaN                        NaN
# 3  001b000003ai0LGAAY                     NaN             OR000040SAB4BM
# 4  001b000003NPIzEAAX                     NaN                        NaN
#
#   onboarding_primary_organisation_id integration_for_payment_creation  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#   onboarding_id customer_success_id campaign_id source_bucket business_unit  \
# 0           NaN                 NaN         NaN       Inbound        France
# 1           NaN                 NaN         NaN      Outbound  UK & Ireland
# 2           NaN                 NaN         NaN       Inbound  UK & Ireland
# 3           NaN                 NaN         NaN       Inbound        Iberia
# 4           NaN                 NaN         NaN       Inbound        Iberia
#
#   opportunity_type opportunity_stage_name opportunity_stage_name_simplified  \
# 0              New               11. Lost                               NaN
# 1              New               11. Lost                               NaN
# 2              New               11. Lost                               NaN
# 3              New               11. Lost                               NaN
# 4              New               11. Lost                               NaN
#
#    opportunity_stage_number  opportunity_won  opportunity_closed  \
# 0                        11            False                True
# 1                        11            False                True
# 2                        11            False                True
# 3                        11            False                True
# 4                        11            False                True
#
#            team                 channel         country country_code  \
# 0         Sales                     NaN          France           FR
# 1  Partnerships                   Event  United Kingdom           GB
# 2         Sales           Printed Press  United Kingdom           GB
# 3         Sales  Partner Recommendation           Spain           ES
# 4         Sales          GC Salesperson           Spain           ES
#
#    contract_length_years commitment_period segment merchant_partner  \
# 0                    NaN               NaN     NaN         Merchant
# 1                    NaN               NaN     NaN         Merchant
# 2                    NaN               NaN     NaN         Merchant
# 3                    NaN               NaN     NaN         Merchant
# 4                    NaN               NaN     NaN         Merchant
#
#           source source_detail salesforce_currency commission_model  \
# 0  Contact Sales           NaN                 GBP              VRA
# 1  Sales Sourced           NaN                 GBP              NaN
# 2  Contact Sales           NaN                 GBP              VRA
# 3     Pro signup           NaN                 GBP              VRA
# 4          Intro           NaN                 GBP              VRA
#
#        opportunity_name opportunity_owner_name  opportunity_owner_is_active  \
# 0        recommerce.com           Louis Taupin                        False
# 1             Cerillion          Tristan Corpe                        False
# 2               ZipJet-             Alex Whyte                        False
# 3  CrossFit Rookies Box            Meri Moreno                        False
# 4              Arcadina            Meri Moreno                        False
#
#   integration_for_payment_creation_name onboarding_analyst  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                                   NaN                NaN
#
#   onboarding_complete onboarding_stage onboarding_ref onboarding_use_case  \
# 0                 NaN              NaN            NaN                 NaN
# 1                 NaN              NaN            NaN                 NaN
# 2                 NaN              NaN            NaN                 NaN
# 3                 NaN              NaN            NaN                 NaN
# 4                 NaN              NaN            NaN                 NaN
#
#   onboarding_ramp_up_method onboarding_has_custom_payment_pages_required  \
# 0                       NaN                                          NaN
# 1                       NaN                                          NaN
# 2                       NaN                                          NaN
# 3                       NaN                                          NaN
# 4                       NaN                                          NaN
#
#   onboarding_has_custom_notifications_required is_onboarding_form_completed  \
# 0                                          NaN                          NaN
# 1                                          NaN                          NaN
# 2                                          NaN                          NaN
# 3                                          NaN                          NaN
# 4                                          NaN                          NaN
#
#   has_onboarding_payout_email_been_sent next_steps  time_to_sign  \
# 0                                   NaN        NaN           198
# 1                                   NaN        NaN           371
# 2                                   NaN        NaN           255
# 3                                   NaN        NaN           150
# 4                                   NaN        NaN           510
#
#    opportunity_created_by_role opportunity_created_by  \
# 0                          CRO     005b0000000O5K9AAK
# 1                          CRO     005b00000040LYuAAM
# 2  ENT Partner Success Manager     005b0000003bjr7AAA
# 3                          NaN     005b0000005267IAAQ
# 4                          CRO     005b0000003A8w1AAC
#
#   opportunity_created_by_division          owner_role  \
# 0                             NaN  Emerging AE France
# 1                             NaN                 NaN
# 2                          Global    Enterprise AE UK
# 3                      UK & Other      Emerging AE UK
# 4                             NaN      Emerging AE UK
#
#   opportunity_owner_division             use_case          account_name  \
# 0                     France                  NaN        recommerce.com
# 1                     Global                  API             Cerillion
# 2                 UK & Other                  NaN                Zipjet
# 3                 UK & Other  Partner_Integration  CROSSFIT ROOKIES BOX
# 4                 UK & Other                  API              Arcadina
#
#   customer_success_intake customer_success_owner account_stage  \
# 0                     NaN                    NaN           NaN
# 1                     NaN                    NaN           NaN
# 2                     NaN                    NaN           NaN
# 3                     NaN                    NaN           NaN
# 4                     NaN                    NaN           NaN
#
#    has_success_plan_link  annual_revenue_db                vertical  \
# 0                  False          3,921.000  Information Technology
# 1                  False     25,000,000.000  Information Technology
# 2                  False      2,063,847.000                Services
# 3                  False                NaN                     NaN
# 4                  False        356,724.000  Information Technology
#
#                     subvertical email_domain audience account_owner_user  \
# 0  Internet Software & Services          NaN      NaN        Carlo Isaia
# 1  Internet Software & Services          NaN      NaN      Anna Tratalos
# 2             Business Services          NaN      NaN        Carlo Isaia
# 3                           NaN          NaN      NaN        Carlo Isaia
# 4  Internet Software & Services          NaN      NaN        Carlo Isaia
#
#   champion economic_buyer decision_maker business_user__c  \
# 0        X              X              X                X
# 1        X              X              X                X
# 2        X              X              X                X
# 3        X              X              X                X
# 4        X              X              X                X
#
#    last_share_of_wallet  days_from_last_share_of_wallet  \
# 0                   NaN                             NaN
# 1                   NaN                             NaN
# 2                   NaN                             NaN
# 3                   NaN                             NaN
# 4                   NaN                             NaN
#
#                                       channel_detail  legacy_exclude_opp  \
# 0                                                NaN               False
# 1                                         Zuora 2016               False
# 2  They are a tech startup too so saw us in articles               False
# 3                                             Teamup               False
# 4                                           Quaderno               False
#
#                     closed_lost_reason  legacy_disqualified_opp  \
# 0                              Nurture                    False
# 1                              Nurture                    False
# 2  Poor Qualification - not fit for DD                    False
# 3                         Unresponsive                    False
# 4                              Nurture                    False
#
#   pipeline_created_by pipeline_created_by_division pipeline_created_by_role  \
# 0                 NaN                          NaN                      NaN
# 1                 NaN                          NaN                      NaN
# 2                 NaN                          NaN                      NaN
# 3                 NaN                          NaN                      NaN
# 4                 NaN                          NaN                      NaN
#
#   record_type  exchange_rate  probability forecast_category_name next_step  \
# 0     Default          1.000            0                Omitted         X
# 1     Default          1.000            0                Omitted         X
# 2     Default          1.000            0                Omitted         X
# 3     Default          1.000            0                Omitted         X
# 4     Default          1.000            0                Omitted         X
#
#    has_contacted_sales  has_contacted_via_chatbot  has_called_sales  \
# 0                False                      False             False
# 1                False                      False             False
# 2                 True                      False             False
# 3                False                      False             False
# 4                False                      False             False
#
#   ramp_up_method is_multischeme schemes manual_support_package_override  \
# 0            NaN          False    BACS                             NaN
# 1            NaN          False    BACS                             NaN
# 2            NaN          False    BACS                             NaN
# 3    Bulk Change          False    SEPA                             NaN
# 4    Bulk Change          False    SEPA                             NaN
#
#   original_opportunity_support_package support_package  \
# 0                                  NaN             NaN
# 1                                  NaN             NaN
# 2                             Enhanced        Enhanced
# 3                                  NaN             NaN
# 4                                  NaN             NaN
#
#   renewal_forecast_category_reason renewal_forecast_reason  \
# 0                              NaN                     NaN
# 1                              NaN                     NaN
# 2                              NaN                     NaN
# 3                              NaN                     NaN
# 4                              NaN                     NaN
#
#    is_borderless_opportunity  sao_count pipeline_source  \
# 0                      False          0       Undefined
# 1                      False          1       Undefined
# 2                      False          0       Undefined
# 3                      False          0       Undefined
# 4                      False          0       Undefined
#
#   pipeline_business_unit  sales_cycle  has_partner_account_record  \
# 0                    NaN          NaN                       False
# 1                    NaN      371.000                       False
# 2                    NaN          NaN                       False
# 3                    NaN          NaN                       False
# 4                    NaN          NaN                       False
#
#    is_support_schedule_requested  has_support_package_discount_approved  \
# 0                          False                                  False
# 1                          False                                  False
# 2                          False                                  False
# 3                          False                                  False
# 4                          False                                  False
#
#    is_land_and_expand pipeline_created_by_growth_engine  \
# 0               False                               NaN
# 1               False                               NaN
# 2               False                               NaN
# 3               False                               NaN
# 4               False                               NaN
#
#   pipeline_growth_engine closed_by_growth_engine  \
# 0                    NaN                     NaN
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
#
#   opportunity_owner_growth_engine growth_engine_account_current  \
# 0                             NaN                Small Business
# 1                             NaN                     Corporate
# 2                       Corporate                      Emerging
# 3                             NaN              To Be Classified
# 4                             NaN                Small Business
#
#   growth_engine_account_at_opp_creation closed_by_division  \
# 0                        Small Business                NaN
# 1                             Corporate                NaN
# 2                              Emerging                NaN
# 3                                   NaN                NaN
# 4                        Small Business                NaN
#
#   missing_feature_details                                 closed_lost_detail  \
# 0                     NaN                               Interested For Later
# 1                     NaN  Not looking to build an integration until mid ...
# 2                     NaN  Decided they'll need an instant payment method...
# 3                     NaN  Not replied my FU emails. I´ll ask TeamUp in o...
# 4                     NaN  Reach out again end of Q2.\nThey want to use u...
#
#   recycled_reason_code revision_reason_code  open_banking_pipeline  \
# 0                  NaN                  NaN                  False
# 1                  NaN                  NaN                  False
# 2                  NaN                  NaN                  False
# 3                  NaN                  NaN                  False
# 4                  NaN                  NaN                  False
#
#    instant_1st_time_payments  merchant_transaction_volumes_acv  \
# 0                      False                               NaN
# 1                      False                               NaN
# 2                      False                               NaN
# 3                      False                               NaN
# 4                      False                               NaN
#
#    commitments_instant_bank_pay  ad_hoc_payments  verified_mandates  \
# 0                           NaN            False              False
# 1                           NaN            False              False
# 2                           NaN            False              False
# 3                           NaN            False              False
# 4                           NaN            False              False
#
#    invoice_payments open_banking_schemes renewal_canx_closed_primary_reason  \
# 0             False                  NaN                                NaN
# 1             False                  NaN                                NaN
# 2             False                  NaN                                NaN
# 3             False                  NaN                                NaN
# 4             False                  NaN                                NaN
#
#   renewal_canx_closed_secondary_reason  is_new_funnel max_stage_reached  \
# 0                                  NaN          False               NaN
# 1                                  NaN          False       1. Discover
# 2                                  NaN          False       1. Discover
# 3                                  NaN          False       1. Discover
# 4                                  NaN          False       1. Discover
#
#    total_acv_local  total_acv_gbp  total_tcv_local  total_tcv_gbp  \
# 0            0.000          0.000            0.000          0.000
# 1            0.000          0.000            0.000          0.000
# 2            0.000          0.000            0.000          0.000
# 3            0.000          0.000            0.000          0.000
# 4            0.000          0.000            0.000          0.000
#
#    total_gross_acv_local  total_gross_acv_gbp  previous_total_gross_acv_local  \
# 0                  0.000                0.000                           0.000
# 1                  0.000                0.000                           0.000
# 2                  0.000                0.000                           0.000
# 3                  0.000                0.000                           0.000
# 4                  0.000                0.000                           0.000
#
#    previous_total_gross_acv_gbp  total_finance_acv_local  \
# 0                         0.000                    0.000
# 1                         0.000                    0.000
# 2                         0.000                    0.000
# 3                         0.000                    0.000
# 4                         0.000                    0.000
#
#    total_finance_acv_gbp  gc_payments_acv_local  gc_payments_acv_gbp  \
# 0                  0.000                  0.000                0.000
# 1                  0.000                  0.000                0.000
# 2                  0.000                  0.000                0.000
# 3                  0.000                  0.000                0.000
# 4                  0.000                  0.000                0.000
#
#    gc_payments_tcv_local  gc_payments_tcv_gbp  gc_payments_gross_acv_local  \
# 0                  0.000                0.000                        0.000
# 1                  0.000                0.000                        0.000
# 2                  0.000                0.000                        0.000
# 3                  0.000                0.000                        0.000
# 4                  0.000                0.000                        0.000
#
#    gc_payments_gross_acv_gbp  gc_payments_finance_acv_local  \
# 0                      0.000                          0.000
# 1                      0.000                          0.000
# 2                      0.000                          0.000
# 3                      0.000                          0.000
# 4                      0.000                          0.000
#
#    gc_payments_finance_acv_gbp  success_acv_local  success_acv_gbp  \
# 0                        0.000              0.000            0.000
# 1                        0.000              0.000            0.000
# 2                        0.000              0.000            0.000
# 3                        0.000              0.000            0.000
# 4                        0.000              0.000            0.000
#
#    success_tcv_local  success_tcv_gbp  success_gross_acv_local  \
# 0              0.000            0.000                    0.000
# 1              0.000            0.000                    0.000
# 2              0.000            0.000                    0.000
# 3              0.000            0.000                    0.000
# 4              0.000            0.000                    0.000
#
#    success_gross_acv_gbp  success_finance_acv_local  success_finance_acv_gbp  \
# 0                  0.000                      0.000                    0.000
# 1                  0.000                      0.000                    0.000
# 2                  0.000                      0.000                    0.000
# 3                  0.000                      0.000                    0.000
# 4                  0.000                      0.000                    0.000
#
#    assumed_acv_local  assumed_acv_gbp  support_package_acv_local  \
# 0          4,800.000        4,800.000                      0.000
# 1         20,000.000       20,000.000                      0.000
# 2          7,500.000        7,500.000                      0.000
# 3              0.000            0.000                      0.000
# 4          4,800.000        4,800.000                      0.000
#
#    support_package_acv_gbp  support_package_gross_acv_local  \
# 0                    0.000                            0.000
# 1                    0.000                            0.000
# 2                    0.000                            0.000
# 3                    0.000                            0.000
# 4                    0.000                            0.000
#
#    support_package_gross_acv_gbp  support_package_finance_acv_local  \
# 0                          0.000                              0.000
# 1                          0.000                              0.000
# 2                          0.000                              0.000
# 3                          0.000                              0.000
# 4                          0.000                              0.000
#
#    support_package_finance_acv_gbp  csm_acv_renewal_forecast_acv_local  \
# 0                            0.000                               0.000
# 1                            0.000                               0.000
# 2                            0.000                               0.000
# 3                            0.000                               0.000
# 4                            0.000                               0.000
#
#    csm_acv_renewal_forecast_acv_gbp success_plus_break_clause_period  \
# 0                             0.000                              NaN
# 1                             0.000                              NaN
# 2                             0.000                              NaN
# 3                             0.000                              NaN
# 4                             0.000                              NaN
#
#   is_poc_opportunity market_country  share_of_wallet share_of_wallet_levers  \
# 0                NaN            NaN              NaN                    NaN
# 1                NaN            NaN              NaN                    NaN
# 2                NaN            NaN              NaN                    NaN
# 3                NaN            NaN              NaN                    NaN
# 4                NaN            NaN              NaN                    NaN
#
#   discount_type_applied onboarding_status_lost_cancelled_date  \
# 0                   NaN                                   NaN
# 1                   NaN                                   NaN
# 2                   NaN                                   NaN
# 3                   NaN                                   NaN
# 4                   NaN                                   NaN
#
#    attribution_touchpoint_count  sales_attribution_touchpoint_count  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#    marketing_attribution_touchpoint_count customer_success_stage  \
# 0                                     NaN                    NaN
# 1                                     NaN                    NaN
# 2                                     NaN                    NaN
# 3                                     NaN                    NaN
# 4                                     NaN                    NaN
#
#   has_kick_off_meeting_scheduled has_success_plan_signoff  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
#
#   customer_success_record_notes opportunity_created_from_account_stage  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#    days_since_last_hie last_hie_meeting_type  days_to_next_hie  \
# 0                  NaN                   NaN               NaN
# 1                  NaN                   NaN               NaN
# 2                  NaN                   NaN               NaN
# 3                  NaN                   NaN               NaN
# 4                  NaN                   NaN               NaN
#
#   next_hie_meeting_type  days_since_last_kick_off  \
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
#
#    days_since_last_success_review salesloft_most_recent_cadence_name  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
#
#    salesloft_most_recent_last_completed_step salesloft_primary_contact  \
# 0                                        NaN                       NaN
# 1                                        NaN                       NaN
# 2                                        NaN                       NaN
# 3                                        NaN                       NaN
# 4                                        NaN                       NaN
#
#   cm_add_success_plus cm_instant_bank_pay cm_language_of_contract  \
# 0                 NaN                 NaN                     NaN
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN                 NaN                     NaN
# 4                 NaN                 NaN                     NaN
#
#   cm_payment_services_agreement cm_verified_mandates  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
#
#                      existing_payment_options current_dd_provider  \
# 0                                         NaN                 NaN
# 1  Credit Cards;Debit Cards;Direct Debit - MA                Bank
# 2                    Credit Cards;Debit Cards                 NaN
# 3                  Bank Transfer;Credit Cards                 NaN
# 4              Credit Cards;Direct Debit - FM                Bank
#
#   legal_matrix_colour  days_mqa_to_discovery mqa_influenced_stage  \
# 0                   X                    NaN                  NaN
# 1                   X                    NaN                  NaN
# 2                   X                    NaN                  NaN
# 3                   X                    NaN                  NaN
# 4                   X                    NaN                  NaN
#
#   opportunity_created_date  opportunity_closed_date  \
# 0  2015-05-17 13:28:49 UTC  2015-12-01 00:00:00 UTC
# 1  2016-11-25 10:51:48 UTC  2017-12-01 00:00:00 UTC
# 2  2016-04-21 14:49:00 UTC  2017-01-01 00:00:00 UTC
# 3  2016-12-02 18:16:46 UTC  2017-05-01 00:00:00 UTC
# 4  2016-05-09 15:37:50 UTC  2017-10-01 00:00:00 UTC
#
#   opportunity_contract_signed_date opportunity_closed_lost_date  \
# 0                              NaN                          NaN
# 1                              NaN      2016-12-12 00:00:00 UTC
# 2                              NaN      2016-07-26 00:00:00 UTC
# 3          2017-02-20 00:00:00 UTC      2017-04-04 00:00:00 UTC
# 4                              NaN      2017-04-04 00:00:00 UTC
#
#      contract_go_live_date    target_rampup_start_c  \
# 0                      NaN                      NaN
# 1  2017-07-01 00:00:00 UTC  2017-07-01 00:00:00 UTC
# 2  2017-01-01 00:00:00 UTC  2017-01-01 00:00:00 UTC
# 3  2017-04-30 00:00:00 UTC  2017-04-30 00:00:00 UTC
# 4  2017-05-01 00:00:00 UTC  2017-05-01 00:00:00 UTC
#
#   taskfeed_board_created_date onboarding_completed_date  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#   onboarding_completed_date_plus_90_days bulk_change_date contract_end_date  \
# 0                                    NaN              NaN               NaN
# 1                                    NaN              NaN               NaN
# 2                                    NaN              NaN               NaN
# 3                                    NaN              NaN               NaN
# 4                                    NaN              NaN               NaN
#
#   previous_contract_end_date opportunity_sdr_quaified_stage_date  \
# 0                        NaN                                 NaN
# 1                        NaN             2016-11-25 15:16:42 UTC
# 2                        NaN             2016-04-22 10:43:46 UTC
# 3                        NaN             2016-12-20 13:50:01 UTC
# 4                        NaN             2016-09-22 09:10:02 UTC
#
#   opportunity_discover_stage_date opportunity_qualify_stage_date  \
# 0                             NaN                            NaN
# 1         2016-11-25 15:16:42 UTC                            NaN
# 2         2016-04-22 10:43:46 UTC                            NaN
# 3         2016-12-20 13:50:01 UTC                            NaN
# 4         2016-09-22 09:10:02 UTC                            NaN
#
#   opportunity_collaborate_stage_date opportunity_confirm_stage_date  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   opportunity_negotiation_stage_date opportunity_signature_stage_date  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
#
#   opportunity_closed_won_stage_date opportunity_closed_lost_stage_date  \
# 0                               NaN            2015-05-17 13:28:49 UTC
# 1                               NaN            2016-12-12 10:01:39 UTC
# 2                               NaN            2016-07-26 12:00:05 UTC
# 3                               NaN            2017-04-04 15:15:06 UTC
# 4                               NaN            2017-04-04 14:35:42 UTC
#
#       discovery_stage_date onboarding_status_forecasted_date  \
# 0                      NaN                               NaN
# 1  2016-11-25 00:00:00 UTC                               NaN
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4                      NaN                               NaN
#
#   onboarding_status_planning_date onboarding_status_new_date  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
#
#   onboarding_status_accepted_date onboarding_status_in_progress_date  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
#
#   onboarding_status_live_date onboarding_status_taking_payments_date  \
# 0                         NaN                                    NaN
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
#
#   onboarding_status_completed_date onboarding_status_on_hold_start_date  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#   onboarding_status_on_hold_end_date  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   customer_success_success_team_allocation_stage_date  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   customer_success_internal_handover_stage_date  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   customer_success_kick_off_meeting_scheduled_date  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   customer_success_kickoff_meeting_stage_date  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   customer_success_success_planning_stage_date  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   customer_success_cs_managed_stage_date  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   customer_success_lost_cancelled_stage_date  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   last_payment_dimension_created_at last_share_of_wallet_created_at  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#   last_hie_at next_hie_at last_kickoff_at last_success_review_at  \
# 0         NaN         NaN             NaN                    NaN
# 1         NaN         NaN             NaN                    NaN
# 2         NaN         NaN             NaN                    NaN
# 3         NaN         NaN             NaN                    NaN
# 4         NaN         NaN             NaN                    NaN
#
#   account_latest_mqa_at
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
list(opportunities_df.columns)
# Out:
# ['opportunity_id',
#  'opportunity_owner_id',
#  'account_id',
#  'parent_account_id',
#  'previous_opportunity_id',
#  'salesforce_organisation_id',
#  'onboarding_primary_organisation_id',
#  'integration_for_payment_creation',
#  'onboarding_id',
#  'customer_success_id',
#  'campaign_id',
#  'source_bucket',
#  'business_unit',
#  'opportunity_type',
#  'opportunity_stage_name',
#  'opportunity_stage_name_simplified',
#  'opportunity_stage_number',
#  'opportunity_won',
#  'opportunity_closed',
#  'team',
#  'channel',
#  'country',
#  'country_code',
#  'contract_length_years',
#  'commitment_period',
#  'segment',
#  'merchant_partner',
#  'source',
#  'source_detail',
#  'salesforce_currency',
#  'commission_model',
#  'opportunity_name',
#  'opportunity_owner_name',
#  'opportunity_owner_is_active',
#  'integration_for_payment_creation_name',
#  'onboarding_analyst',
#  'onboarding_complete',
#  'onboarding_stage',
#  'onboarding_ref',
#  'onboarding_use_case',
#  'onboarding_ramp_up_method',
#  'onboarding_has_custom_payment_pages_required',
#  'onboarding_has_custom_notifications_required',
#  'is_onboarding_form_completed',
#  'has_onboarding_payout_email_been_sent',
#  'next_steps',
#  'time_to_sign',
#  'opportunity_created_by_role',
#  'opportunity_created_by',
#  'opportunity_created_by_division',
#  'owner_role',
#  'opportunity_owner_division',
#  'use_case',
#  'account_name',
#  'customer_success_intake',
#  'customer_success_owner',
#  'account_stage',
#  'has_success_plan_link',
#  'annual_revenue_db',
#  'vertical',
#  'subvertical',
#  'email_domain',
#  'audience',
#  'account_owner_user',
#  'champion',
#  'economic_buyer',
#  'decision_maker',
#  'business_user__c',
#  'last_share_of_wallet',
#  'days_from_last_share_of_wallet',
#  'channel_detail',
#  'legacy_exclude_opp',
#  'closed_lost_reason',
#  'legacy_disqualified_opp',
#  'pipeline_created_by',
#  'pipeline_created_by_division',
#  'pipeline_created_by_role',
#  'record_type',
#  'exchange_rate',
#  'probability',
#  'forecast_category_name',
#  'next_step',
#  'has_contacted_sales',
#  'has_contacted_via_chatbot',
#  'has_called_sales',
#  'ramp_up_method',
#  'is_multischeme',
#  'schemes',
#  'manual_support_package_override',
#  'original_opportunity_support_package',
#  'support_package',
#  'renewal_forecast_category_reason',
#  'renewal_forecast_reason',
#  'is_borderless_opportunity',
#  'sao_count',
#  'pipeline_source',
#  'pipeline_business_unit',
#  'sales_cycle',
#  'has_partner_account_record',
#  'is_support_schedule_requested',
#  'has_support_package_discount_approved',
#  'is_land_and_expand',
#  'pipeline_created_by_growth_engine',
#  'pipeline_growth_engine',
#  'closed_by_growth_engine',
#  'opportunity_owner_growth_engine',
#  'growth_engine_account_current',
#  'growth_engine_account_at_opp_creation',
#  'closed_by_division',
#  'missing_feature_details',
#  'closed_lost_detail',
#  'recycled_reason_code',
#  'revision_reason_code',
#  'open_banking_pipeline',
#  'instant_1st_time_payments',
#  'merchant_transaction_volumes_acv',
#  'commitments_instant_bank_pay',
#  'ad_hoc_payments',
#  'verified_mandates',
#  'invoice_payments',
#  'open_banking_schemes',
#  'renewal_canx_closed_primary_reason',
#  'renewal_canx_closed_secondary_reason',
#  'is_new_funnel',
#  'max_stage_reached',
#  'total_acv_local',
#  'total_acv_gbp',
#  'total_tcv_local',
#  'total_tcv_gbp',
#  'total_gross_acv_local',
#  'total_gross_acv_gbp',
#  'previous_total_gross_acv_local',
#  'previous_total_gross_acv_gbp',
#  'total_finance_acv_local',
#  'total_finance_acv_gbp',
#  'gc_payments_acv_local',
#  'gc_payments_acv_gbp',
#  'gc_payments_tcv_local',
#  'gc_payments_tcv_gbp',
#  'gc_payments_gross_acv_local',
#  'gc_payments_gross_acv_gbp',
#  'gc_payments_finance_acv_local',
#  'gc_payments_finance_acv_gbp',
#  'success_acv_local',
#  'success_acv_gbp',
#  'success_tcv_local',
#  'success_tcv_gbp',
#  'success_gross_acv_local',
#  'success_gross_acv_gbp',
#  'success_finance_acv_local',
#  'success_finance_acv_gbp',
#  'assumed_acv_local',
#  'assumed_acv_gbp',
#  'support_package_acv_local',
#  'support_package_acv_gbp',
#  'support_package_gross_acv_local',
#  'support_package_gross_acv_gbp',
#  'support_package_finance_acv_local',
#  'support_package_finance_acv_gbp',
#  'csm_acv_renewal_forecast_acv_local',
#  'csm_acv_renewal_forecast_acv_gbp',
#  'success_plus_break_clause_period',
#  'is_poc_opportunity',
#  'market_country',
#  'share_of_wallet',
#  'share_of_wallet_levers',
#  'discount_type_applied',
#  'onboarding_status_lost_cancelled_date',
#  'attribution_touchpoint_count',
#  'sales_attribution_touchpoint_count',
#  'marketing_attribution_touchpoint_count',
#  'customer_success_stage',
#  'has_kick_off_meeting_scheduled',
#  'has_success_plan_signoff',
#  'customer_success_record_notes',
#  'opportunity_created_from_account_stage',
#  'days_since_last_hie',
#  'last_hie_meeting_type',
#  'days_to_next_hie',
#  'next_hie_meeting_type',
#  'days_since_last_kick_off',
#  'days_since_last_success_review',
#  'salesloft_most_recent_cadence_name',
#  'salesloft_most_recent_last_completed_step',
#  'salesloft_primary_contact',
#  'cm_add_success_plus',
#  'cm_instant_bank_pay',
#  'cm_language_of_contract',
#  'cm_payment_services_agreement',
#  'cm_verified_mandates',
#  'existing_payment_options',
#  'current_dd_provider',
#  'legal_matrix_colour',
#  'days_mqa_to_discovery',
#  'mqa_influenced_stage',
#  'opportunity_created_date',
#  'opportunity_closed_date',
#  'opportunity_contract_signed_date',
#  'opportunity_closed_lost_date',
#  'contract_go_live_date',
#  'target_rampup_start_c',
#  'taskfeed_board_created_date',
#  'onboarding_completed_date',
#  'onboarding_completed_date_plus_90_days',
#  'bulk_change_date',
#  'contract_end_date',
#  'previous_contract_end_date',
#  'opportunity_sdr_quaified_stage_date',
#  'opportunity_discover_stage_date',
#  'opportunity_qualify_stage_date',
#  'opportunity_collaborate_stage_date',
#  'opportunity_confirm_stage_date',
#  'opportunity_negotiation_stage_date',
#  'opportunity_signature_stage_date',
#  'opportunity_closed_won_stage_date',
#  'opportunity_closed_lost_stage_date',
#  'discovery_stage_date',
#  'onboarding_status_forecasted_date',
#  'onboarding_status_planning_date',
#  'onboarding_status_new_date',
#  'onboarding_status_accepted_date',
#  'onboarding_status_in_progress_date',
#  'onboarding_status_live_date',
#  'onboarding_status_taking_payments_date',
#  'onboarding_status_completed_date',
#  'onboarding_status_on_hold_start_date',
#  'onboarding_status_on_hold_end_date',
#  'customer_success_success_team_allocation_stage_date',
#  'customer_success_internal_handover_stage_date',
#  'customer_success_kick_off_meeting_scheduled_date',
#  'customer_success_kickoff_meeting_stage_date',
#  'customer_success_success_planning_stage_date',
#  'customer_success_cs_managed_stage_date',
#  'customer_success_lost_cancelled_stage_date',
#  'last_payment_dimension_created_at',
#  'last_share_of_wallet_created_at',
#  'last_hie_at',
#  'next_hie_at',
#  'last_kickoff_at',
#  'last_success_review_at',
#  'account_latest_mqa_at']

# %%
# N opportunities
opportunities_df.opportunity_id.nunique()
# Out:
# 20809

# %% [markdown]
# ### Explore categoricals

# %% [markdown]
# #### Opportunity types and stages

# %%
# Opportunity type
opportunities_df['opportunity_type'].value_counts(dropna=False)
# Out:
# New             15235
# Renewal          3267
# Conversion       1366
# Upsell            701
# Cancellation      133
# Expansion          78
# Downsell           30
# Name: opportunity_type, dtype: int64

# %%
# opportunity_stage_name
opportunities_df['opportunity_stage_name'].value_counts(dropna=False)
# Out:
# 8. Closed Lost               6456
# 7. Closed Won                4795
# 1. Discovery                 1965
# 11. Lost                     1885
# 10. Ramped                   1662
# 12. Disqualified             1471
# 8. Closed - Recycled          496
# 8. Closed - Disqualified      481
# 0. SDR Qualified              363
# Live - Self-Serve             324
# 3. Collaborate                159
# 9. Taking Payments            145
# 0. Revision                   121
# 2. Qualify                    120
# 13. Churned                    91
# Closed Won                     77
# 5. Negotiation                 52
# 4. Confirm                     50
# 7. Setup                       44
# 8. Minimum Commit Started      29
# 6. Signature                   17
# 7. Closed Lost                  7
# Name: opportunity_stage_name, dtype: int64

# %%
fig, ax = plt.subplots()
opportunities_df['opportunity_stage_name'].value_counts(dropna=False).sort_values().plot(kind = 'barh', color="#046E8F", ax=ax)
ax.set_xlabel("Number of opportunities")
plt.title("Opportunity stage name counts")
plt.show();

# %%
# Focus on closed lost vs. closed won
closed_opps_df = opportunities_df[opportunities_df['opportunity_stage_name'].isin(['8. Closed Lost', '7. Closed Won'])]

# %%
# Why is 'closed won' so high?

# %%
closed_opps_df.shape
# Out:
# (11251, 241)

# %% [markdown]
# #### Team

# %%
# Team
closed_opps_df['team'].value_counts()
# Out:
# Sales                     7793
# Customer                  1611
# Marketing                  585
# Customer Success Group     416
# Partnerships               291
# Customer Success            91
# Name: team, dtype: int64

# %%
# channel - doesn't look useful
# closed_opps_df[['team', 'channel']].value_counts()
closed_opps_df.groupby(['team', 'channel']).size()
# Out:
# team                    channel
# Customer                End Customer User                        3
#                         GC Salesperson                           3
#                         Legacy Unknown                           1
#                         Non Partner Recommendation               1
#                         Not yet known                           10
#                         Other                                    1
#                         Web Search (Google, Bing Yahoo etc)      1
# Customer Success        GC Salesperson                           1
#                         Legacy Unknown                           1
#                         Not yet known                           12
# Customer Success Group  End Customer User                        1
# Marketing               Direct Mail                              1
#                         Email                                    7
#                         End Customer User                       25
#                         Event                                   13
#                         GC Salesperson                          37
#                         Legacy Unknown                          43
#                         Mail Campaign                            3
#                         Non Partner Recommendation              16
#                         Not yet known                          190
#                         Other                                   25
#                         Other Website                            3
#                         Partner Recommendation                  10
#                         Referral Partner Programme               1
#                         SFDC AppExchange                         1
#                         Social Media                             2
#                         Web Search (Google, Bing Yahoo etc)     25
#                         Webinar                                  1
# Partnerships            End Customer User                       15
#                         Event                                   13
#                         GC Salesperson                          59
#                         Legacy Unknown                          30
#                         Mail Campaign                            3
#                         Non Partner Recommendation              16
#                         Not yet known                           30
#                         Other                                    9
#                         Partner Recommendation                  18
#                         Referral Partner Programme               2
#                         Web Search (Google, Bing Yahoo etc)     34
#                         Webinar                                  1
# Sales                   Content Syndication                     11
#                         Direct Mail                             19
#                         Email                                   47
#                         End Customer User                      120
#                         Event                                  192
#                         GC Salesperson                         841
#                         Legacy Unknown                         248
#                         Mail Campaign                           23
#                         Non Partner Recommendation             212
#                         Not yet known                          777
#                         Other                                  106
#                         Other - Please Clarify                   1
#                         Other Website                           16
#                         Partner Recommendation                 535
#                         Printed Press                            7
#                         Referral Partner Programme              13
#                         Review Platform                          2
#                         SFDC AppExchange                         5
#                         Social Media                            58
#                         Unknown                                  3
#                         Web Search (Google, Bing Yahoo etc)    397
#                         Webinar                                 14
# dtype: int64

# %% [markdown]
# #### Country

# %%
# Country
closed_opps_df.groupby(['opportunity_stage_name', 'country']).size().to_frame('n').sort_values(by=['opportunity_stage_name', 'n'], ascending=False)
# Out:
#                                                       n
# opportunity_stage_name country
# 8. Closed Lost         United Kingdom              4192
#                        France                       783
#                        Germany                      437
#                        United States                312
#                        Australia                    306
#                        Spain                        120
#                        New Zealand                   78
#                        Ireland                       63
#                        Canada                        32
#                        Netherlands                   26
#                        Italy                         15
#                        Austria                       14
#                        Belgium                       14
#                        Sweden                        14
#                        Denmark                       10
#                        Portugal                       6
#                        European Union                 5
#                        Switzerland                    4
#                        Malta                          3
#                        United States of America       3
#                        Guadeloupe                     2
#                        Belarus                        1
#                        Czech Republic                 1
#                        Finland                        1
#                        French Guiana                  1
#                        Ghana                          1
#                        Greece                         1
#                        Israel                         1
#                        Luxembourg                     1
#                        Mayotte                        1
#                        Monaco                         1
#                        Norway                         1
#                        Reunion                        1
#                        Réunion                        1
#                        South Africa                   1
#                        UK                             1
#                        United Arab Emirates           1
# 7. Closed Won          United Kingdom              3661
#                        France                       489
#                        Germany                      202
#                        Australia                    120
#                        Spain                         82
#                        United States                 64
#                        Ireland                       39
#                        New Zealand                   39
#                        Italy                         18
#                        Canada                        17
#                        Netherlands                   16
#                        Denmark                        9
#                        Malta                          6
#                        Sweden                         6
#                        Austria                        5
#                        Belgium                        4
#                        Switzerland                    4
#                        Guadeloupe                     2
#                        Norway                         2
#                        United States of America       2
#                        European Union                 1
#                        Finland                        1
#                        Gibraltar                      1
#                        Poland                         1
#                        Portugal                       1
#                        Réunion                        1
#                        Saint Martin (French part)     1

# %% [markdown]
# #### Contract length
#
# * What does it mean to have contract length if lost?

# %%
# contract length - why do lost have contract length?
closed_opps_df.groupby(['opportunity_stage_name', 'contract_length_years'], dropna=False).size().to_frame('n').sort_values(by=['opportunity_stage_name', 'n'], ascending=False)
# Out:
#                                                  n
# opportunity_stage_name contract_length_years
# 8. Closed Lost         NaN                    4236
#                        1.000                  1582
#                        3.000                   426
#                        2.000                   201
#                        0.000                     6
#                        5.000                     3
#                        4.000                     2
# 7. Closed Won          1.000                  3053
#                        NaN                     803
#                        3.000                   597
#                        2.000                   293
#                        0.000                    35
#                        4.000                     8
#                        5.000                     6

# %% [markdown]
# #### segment

# %%
# segment - lots of NA for both groups
closed_opps_df.groupby(['opportunity_stage_name', 'segment'], dropna=False).size().to_frame('n').sort_values(by=['opportunity_stage_name', 'n'], ascending=False)
# Out:
#                                                         n
# opportunity_stage_name segment
# 8. Closed Lost         NaN                           3932
#                        Traditional DD Subscriptions   696
#                        New DD Subscriptions           624
#                        Small Invoicers                529
#                        New DD Invoicers               202
#                        Traditional DD Invoicers       197
#                        Invoicing Scale Ups            137
#                        Instalments                     72
#                        Small Subscriptions             67
# 7. Closed Won          NaN                           2956
#                        Traditional DD Subscriptions   495
#                        New DD Subscriptions           398
#                        Small Invoicers                397
#                        Traditional DD Invoicers       175
#                        New DD Invoicers               140
#                        Invoicing Scale Ups             92
#                        Small Subscriptions             91
#                        Instalments                     51

# %% [markdown]
# #### opportunity_owner_division

# %%
# opportunity_owner_division
closed_opps_df['opportunity_owner_division'].value_counts(dropna=False)
# Out:
# UK & Other        5793
# Global            2054
# France            1234
# ANZ                580
# DACH               556
# North America      470
# NaN                466
# Small Business      96
# Uk & Other           2
# Name: opportunity_owner_division, dtype: int64

# %% [markdown]
# #### merchant_partner
#
# * In the previous analysis they said 'partner' was an important features in predicting conversion probability...this doesn't look large enough though? What is 'partner'?

# %%
# merchant_partner
closed_opps_df['merchant_partner'].value_counts(dropna=False)
# Out:
# Merchant    10863
# Partner       388
# Name: merchant_partner, dtype: int64

# %% [markdown]
# #### commission_model
#
# * VRA vs. CRA - think this makes sense?
# * Should we focus on just one of them?

# %%
# commission_model
closed_opps_df.groupby(['opportunity_stage_name', 'commission_model'], dropna=False).size()
# Out:
# opportunity_stage_name  commission_model
# 7. Closed Won           CRA                 3844
#                         VRA                  730
#                         NaN                  221
# 8. Closed Lost          CRA                 5007
#                         VRA                 1330
#                         NaN                  119
# dtype: int64

# %% [markdown]
# #### Account stage
#
# * Not sure what this is

# %%
# account_stage
closed_opps_df['account_stage'].value_counts(dropna=False)
# Out:
# NaN                    7051
# CS Managed - SB        2888
# CS Managed - Ent&MM     801
# Churned - SB            431
# Churned - Ent&MM         73
# CS_Watchlist              4
# CS Reactive               3
# Name: account_stage, dtype: int64

# %% [markdown]
# #### Revenue, employees, size
#
# * The revenue numbers look suspiciously round

# %%
# annual_revenue_db - account level
closed_opps_df['annual_revenue_db']
# Out:
# 6032        25,000,000.000
# 6033         5,000,000.000
# 6034         5,000,000.000
# 6035         5,000,000.000
# 6036        25,000,000.000
#                ...
# 17496      375,000,000.000
# 17497       25,000,000.000
# 17498   10,000,000,001.000
# 17499       25,000,000.000
# 17500          273,056.000
# Name: annual_revenue_db, Length: 11251, dtype: float64

# %%
avg_revenue = closed_opps_df.groupby("account_id")["annual_revenue_db"].mean()

# %%
avg_revenue.hist();

# %%
avg_revenue = avg_revenue[avg_revenue < 1e9]

# %%
len(avg_revenue)
# Out:
# 6662

# %%
avg_revenue.hist();

# %%
ax = avg_revenue[avg_revenue < 1e7].hist(bins=20, color="#72BDA3", figsize=(10, 5));
ax.set(title='Histogram of revenues\n<1e7')
ax.set_xlabel("£")
plt.show();

# %%
# Multiplying by FX
closed_opps_df['annual_revenue_db_conv'] = closed_opps_df['annual_revenue_db'] * closed_opps_df['exchange_rate']

# %%
ax = closed_opps_df['annual_revenue_db_conv'].hist(bins=20, color="#72BDA3", figsize=(10, 5));
ax.set(title='Histogram of revenues (converted)')
ax.set_xlabel("£")
plt.show();

# %% [markdown]
# - Looks like random number entries?

# %%
avg_revenue.value_counts(dropna=False) / len(avg_revenue)
# Out:
# 5,000,000.000     0.278
# 25,000,000.000    0.127
# 500,000.000       0.094
# 175,000,000.000   0.027
# 75,000,000.000    0.026
#                    ...
# 147,617,111.000   0.000
# 107,603,035.000   0.000
# 101,423,587.000   0.000
# 884,364,000.000   0.000
# 6,223,837.000     0.000
# Name: annual_revenue_db, Length: 2463, dtype: float64

# %%
# revenue
print(f'mean revenue: {closed_opps_df.groupby("account_id")["annual_revenue_db"].mean().mean()}')
print(f'min revenue: {closed_opps_df.groupby("account_id")["annual_revenue_db"].mean().min()}')
print(f'max revenue: {closed_opps_df.groupby("account_id")["annual_revenue_db"].mean().max()}')
# Out:
# mean revenue: 679773254.920658
# min revenue: 0.0
# max revenue: 866000000000.0

# %% [markdown]
# #### Contract values

# %%
# total_acv_local - customer value?
print(f'mean total_acv_local: {closed_opps_df.groupby("account_id")["total_acv_local"].max().mean()}')
print(f'min total_acv_local: {closed_opps_df.groupby("account_id")["total_acv_local"].max().min()}')
print(f'max total_acv_local: {closed_opps_df.groupby("account_id")["total_acv_local"].max().max()}')
# Out:
# mean total_acv_local: 13877.580692981343
# min total_acv_local: -20028.0
# max total_acv_local: 1188764.0

# %%
# closed_opps_df
closed_opps_df['total_acv_local'].head()
# Out:
# 6032   49,800.000
# 6033   11,250.000
# 6034        0.000
# 6035   36,196.000
# 6036   15,184.000
# Name: total_acv_local, dtype: float64

# %%
for i in closed_opps_df.iloc[:,125:161].columns:
    
    print(i)
    print(f'missing: {sum(closed_opps_df[i].isna())}')
    print(f'raw mean: {closed_opps_df[i].mean()}')
    x_no_out = closed_opps_df[i][(closed_opps_df[i] < closed_opps_df[i].quantile(0.99)) & (closed_opps_df[i] > 0)]
    print(f'mean lose top %: {x_no_out.mean()}')
    print('   ')
    x_no_out.hist(bins=20)
    plt.show();
    print('----')
# Out:
# total_acv_local
# missing: 0
# raw mean: 10999.251275442182
# mean lose top %: 14772.556966447064
# ----
# total_acv_gbp
# missing: 5
# raw mean: 10019.166910797403
# mean lose top %: 13431.684338023426
# ----
# total_tcv_local
# missing: 0
# raw mean: 13836.589568927207
# mean lose top %: 19777.491563554555
# ----
# total_tcv_gbp
# missing: 5
# raw mean: 12615.822481891195
# mean lose top %: 17975.60907628989
# ----
# total_gross_acv_local
# missing: 0
# raw mean: 8179.30183894765
# mean lose top %: 12796.681133086115
# ----
# total_gross_acv_gbp
# missing: 5
# raw mean: 7358.215355749389
# mean lose top %: 11531.05378832689
# ----
# previous_total_gross_acv_local
# missing: 0
# raw mean: 2623.5752004266287
# mean lose top %: 5730.1584955752205
# ----
# previous_total_gross_acv_gbp
# missing: 5
# raw mean: 2364.121771940473
# mean lose top %: 5200.196342018434
# ----
# total_finance_acv_local
# missing: 0
# raw mean: 7705.313695671494
# mean lose top %: 13452.530755030077
# ----
# total_finance_acv_gbp
# missing: 5
# raw mean: 7097.849969237808
# mean lose top %: 12547.936034513394
# ----
# gc_payments_acv_local
# missing: 0
# raw mean: 10628.688561563142
# mean lose top %: 14306.504272952734
# ----
# gc_payments_acv_gbp
# missing: 5
# raw mean: 9669.542183394182
# mean lose top %: 13184.396085052165
# ----
# gc_payments_tcv_local
# missing: 0
# raw mean: 13417.232380087207
# mean lose top %: 22525.113407516525
# ----
# gc_payments_tcv_gbp
# missing: 5
# raw mean: 12366.93040694405
# mean lose top %: 20853.858792186475
# ----
# gc_payments_gross_acv_local
# missing: 0
# raw mean: 7844.826662162474
# mean lose top %: 12349.098184973445
# ----
# gc_payments_gross_acv_gbp
# missing: 5
# raw mean: 7045.5351999784125
# mean lose top %: 11122.353082108852
# ----
# gc_payments_finance_acv_local
# missing: 0
# raw mean: 7360.662801786143
# mean lose top %: 13189.032450890345
# ----
# gc_payments_finance_acv_gbp
# missing: 5
# raw mean: 6773.617302647021
# mean lose top %: 12135.194112635249
# ----
# success_acv_local
# missing: 0
# raw mean: 123.46481823837883
# mean lose top %: 914.7465702479338
# ----
# success_acv_gbp
# missing: 5
# raw mean: 119.61029517777013
# mean lose top %: 897.5822052541257
# ----
# success_tcv_local
# missing: 0
# raw mean: 213.17306135766322
# mean lose top %: 1417.6937634408605
# ----
# success_tcv_gbp
# missing: 5
# raw mean: 203.4942207477038
# mean lose top %: 1397.5758583736304
# ----
# success_gross_acv_local
# missing: 0
# raw mean: 132.88833674046754
# mean lose top %: 984.4494074074073
# ----
# success_gross_acv_gbp
# missing: 5
# raw mean: 128.71456386352506
# mean lose top %: 955.5716457817105
# ----
# success_finance_acv_local
# missing: 0
# raw mean: 140.10431783841437
# mean lose top %: 958.8766929133858
# ----
# success_finance_acv_gbp
# missing: 5
# raw mean: 135.93375320489088
# mean lose top %: 940.2619727145608
# ----
# assumed_acv_local
# missing: 0
# raw mean: 10675.816910496846
# mean lose top %: 13911.472604581675
# ----
# assumed_acv_gbp
# missing: 5
# raw mean: 9676.843594897244
# mean lose top %: 12921.120082570726
# ----
# support_package_acv_local
# missing: 0
# raw mean: 268.3511750066661
# mean lose top %: 6803.829473684211
# ----
# support_package_acv_gbp
# missing: 5
# raw mean: 248.6248160726206
# mean lose top %: 6271.101793768465
# ----
# support_package_gross_acv_local
# missing: 0
# raw mean: 207.71710070215983
# mean lose top %: 6030.254769230769
# ----
# support_package_gross_acv_gbp
# missing: 5
# raw mean: 189.9883388940682
# mean lose top %: 5730.383895200391
# ----
# support_package_finance_acv_local
# missing: 0
# raw mean: 210.67683761443428
# mean lose top %: 6010.099393939394
# ----
# support_package_finance_acv_gbp
# missing: 5
# raw mean: 194.32166140874006
# mean lose top %: 5709.737269898892
# ----
# csm_acv_renewal_forecast_acv_local
# missing: 0
# raw mean: 466.4627846413652
# mean lose top %: nan
# ----
# csm_acv_renewal_forecast_acv_gbp
# missing: 5
# raw mean: 415.732872871994
# mean lose top %: nan
# ----

# %% [markdown]
# #### merchant_transaction_volumes_acv

# %%
# merchant_transaction_volumes_acv
closed_opps_df['merchant_transaction_volumes_acv'].isna().sum() / closed_opps_df.shape[0]
# Out:
# 0.9247178028619678

# %% [markdown]
# #### Audience
#
# * Not sure what this is

# %%
# audience
closed_opps_df['audience'].value_counts(dropna=False)
# Out:
# NaN                            10593
# OB - High-fit sub verticals      412
# OB - Expansion segments          246
# Name: audience, dtype: int64

# %% [markdown]
# #### Ramp-up
#
# * Not sure what this is

# %%
# ramp_up_method - what is this?
closed_opps_df['ramp_up_method'].value_counts(dropna=False)
# Out:
# Self-Ramp               5154
# NaN                     4487
# Bulk Change             1592
# Internal Bulk Change      18
# Name: ramp_up_method, dtype: int64

# %% [markdown]
# #### attribution_touchpoint_count

# %%
# attribution_touchpoint_count
closed_opps_df['attribution_touchpoint_count'][closed_opps_df['attribution_touchpoint_count'] < 100].hist(bins=20);

# %% [markdown]
# #### customer_success_stage

# %%
# customer_success_stage
closed_opps_df.groupby(['opportunity_stage_name', 'customer_success_stage'], dropna=False).size()
# Out:
# opportunity_stage_name  customer_success_stage
# 7. Closed Won           CS Managed                  662
#                         Internal Handover           123
#                         Kick-off Meeting             21
#                         Lost/Cancelled               11
#                         Success Planning             82
#                         Success Team Allocation      22
#                         NaN                        3874
# 8. Closed Lost          CS Managed                   22
#                         Lost/Cancelled              202
#                         Success Team Allocation       9
#                         NaN                        6223
# dtype: int64

# %% [markdown]
# #### has_kick_off_meeting_scheduled

# %%
# What does this mean? 
closed_opps_df.groupby(['opportunity_stage_name', 'has_kick_off_meeting_scheduled'], dropna=False).size()
# Out:
# opportunity_stage_name  has_kick_off_meeting_scheduled
# 7. Closed Won           False                              374
#                         True                               547
#                         NaN                               3874
# 8. Closed Lost          False                              225
#                         True                                 8
#                         NaN                               6223
# dtype: int64

# %% [markdown]
# #### days_since_last_hie

# %%
# days_since_last_hie?
closed_opps_df.groupby(['opportunity_stage_name', 'days_since_last_hie'], dropna=False).size().head()
# Out:
# opportunity_stage_name  days_since_last_hie
# 7. Closed Won           0.000                  2
#                         3.000                  5
#                         4.000                  9
#                         5.000                  2
#                         6.000                  9
# dtype: int64

# %% [markdown]
# - mostly missing

# %% [markdown]
# #### Vertical

# %%
closed_opps_df['vertical'].value_counts(dropna=False)
# Out:
# Information Technology            1947
# Services                          1536
# NaN                               1528
# Financial Services                1278
# Communications and Media           875
# Consumer Goods                     777
# Health and Wellbeing               499
# Property                           363
# Membership Organisations           342
# Education and Training             340
# Energy                             322
# Nonclassifiable Establishments     262
# Insurance                          255
# Transportation                     234
# Government                         211
# NGO                                157
# Amusement and Recreation           120
# Industrials                         85
# Travel                              74
# Materials                           43
# Gambling                             3
# Name: vertical, dtype: int64

# %%
closed_opps_df['subvertical'].value_counts(dropna=False).head(20)
# Out:
# NaN                                                 1853
# Internet Software & Services                        1577
# Business Services                                   1006
# Accountancy                                          440
# Diversified                                          362
# Personal Services                                    299
# System Software                                      277
# Telecom                                              263
# Nonclassifiable Establishments                       262
# Banks                                                235
# HoldCo                                               222
# Colleges, Universities, and Professional Schools     219
# Professional Bodies / Associations                   212
# Estate Agents                                        208
# Publishing                                           207
# Food Related                                         199
# Gyms                                                 192
# Road & Rail                                          180
# Lending & Financing                                  178
# Utility - Electric                                   161
# Name: subvertical, dtype: int64

# %% [markdown]
# #### use_case

# %%
closed_opps_df['use_case'].value_counts(dropna=False)
# Out:
# NaN                          5217
# Partner_Integration          2553
# API                          1892
# Dashboard                    1566
# Partner Integration            17
# Subscriptions                   3
# Invoicing                       2
# Integrated to InHouse App       1
# Name: use_case, dtype: int64

# %% [markdown]
# #### Share of wallet

# %%
closed_opps_df['last_share_of_wallet'].value_counts(dropna=False).head()
# Out:
# NaN        10166
# 100.000      295
# 95.000        88
# 10.000        72
# 80.000        64
# Name: last_share_of_wallet, dtype: int64

# %% [markdown]
# - what is this?
# - vast maj nulls

# %%
closed_opps_df['days_from_last_share_of_wallet'].value_counts(dropna=False).head()
# Out:
# NaN        10166
# 740.000      503
# 151.000       77
# 146.000       41
# 483.000       29
# Name: days_from_last_share_of_wallet, dtype: int64

# %%
closed_opps_df['share_of_wallet'].value_counts(dropna=False).head(15)
# Out:
# NaN        8487
# 0.000       995
# 100.000     800
# 50.000      220
# 90.000      151
# 80.000      106
# 75.000       87
# 20.000       48
# 70.000       45
# 60.000       42
# 10.000       41
# 30.000       41
# 95.000       35
# 40.000       30
# 25.000       25
# Name: share_of_wallet, dtype: int64

# %%
closed_opps_df['share_of_wallet_levers'].value_counts(dropna=False).head()
# Out:
# NaN                          11175
# Scheme Expansion                18
# Existing Payees Expansion       12
# Use Case Expansion              11
# BU Expansion                    11
# Name: share_of_wallet_levers, dtype: int64

# %% [markdown]
# #### record_type

# %%
closed_opps_df['record_type'].value_counts(dropna=False)
# Out:
# Emerging Opportunity             7867
# Enterprise Opportunity           1451
# Corporate Opportunity            1207
# Partner Opportunity               388
# SB Opportunity                    301
# Global Enterprise Opportunity      33
# Success+ Break Clause Opp           4
# Name: record_type, dtype: int64

# %% [markdown]
# #### has_contacted_sales

# %%
closed_opps_df['has_contacted_sales'].value_counts(dropna=False)
# Out:
# False    9606
# True     1645
# Name: has_contacted_sales, dtype: int64

# %%
closed_opps_df['has_contacted_sales'].value_counts(dropna=False)
# Out:
# False    9606
# True     1645
# Name: has_contacted_sales, dtype: int64

# %%
closed_opps_df['has_contacted_via_chatbot'].value_counts(dropna=False)
# Out:
# False    10945
# True       306
# Name: has_contacted_via_chatbot, dtype: int64

# %% [markdown]
# #### schemes

# %%
closed_opps_df['schemes'].value_counts(dropna=False).head(10)
# Out:
# NaN                               4163
# BACS                              3759
# SEPA                              2138
# BECS                               321
# BACS;SEPA                          210
# ACH                                139
# BECS NZ                             98
# BACS;SEPA;ACH                       58
# BACS;SEPA;BECS;BECS NZ;PAD;ACH      27
# BECS;BECS NZ                        23
# Name: schemes, dtype: int64

# %% [markdown]
# #### support_package

# %%
closed_opps_df['support_package'].value_counts(dropna=False).head(10)
# Out:
# NaN           3788
# Essentials    3428
# Enhanced      3041
# Premium        994
# Name: support_package, dtype: int64

# %% [markdown]
# #### sao_count
#
# - what is this?

# %%
closed_opps_df['sao_count'].value_counts(dropna=False).head(10)
# Out:
# 1    8802
# 0    2449
# Name: sao_count, dtype: int64

# %% [markdown]
# #### open_banking_pipeline

# %%
closed_opps_df['open_banking_pipeline'].value_counts(dropna=False).head(10)
# Out:
# False    10979
# True       272
# Name: open_banking_pipeline, dtype: int64

# %% [markdown]
# #### instant_1st_time_payments

# %%
closed_opps_df['instant_1st_time_payments'].value_counts(dropna=False).head(10)
# Out:
# False    11036
# True       215
# Name: instant_1st_time_payments, dtype: int64

# %% [markdown]
# #### merchant_transaction_volumes_acv

# %%
closed_opps_df['merchant_transaction_volumes_acv'].value_counts(dropna=False).head(10)
# Out:
# NaN           10404
# 0.000           122
# 6,000.000        84
# 5,000.000        24
# 4,800.000        13
# 12,000.000       13
# 10,000.000       12
# 4,000.000        11
# 15,000.000       11
# 30,000.000       10
# Name: merchant_transaction_volumes_acv, dtype: int64

# %% [markdown]
# #### invoice_payments

# %%
closed_opps_df['invoice_payments'].value_counts(dropna=False)
# Out:
# False    9044
# True       35
# Name: invoice_payments, dtype: int64

# %% [markdown]
# #### commitments_instant_bank_pay

# %%
closed_opps_df['commitments_instant_bank_pay'].value_counts(dropna=False).head(10)
# Out:
# NaN           11017
# 0.000           128
# 1,000.000        10
# 200.000           9
# 500.000           5
# 100.000           5
# 600.000           4
# 50.000            4
# 10.000            4
# 50,000.000        3
# Name: commitments_instant_bank_pay, dtype: int64

# %% [markdown]
# #### ad_hoc_payments

# %%
closed_opps_df['ad_hoc_payments'].value_counts(dropna=False).head(10)
# Out:
# False    11138
# True       113
# Name: ad_hoc_payments, dtype: int64

# %% [markdown]
# #### verified_mandates

# %%
closed_opps_df['verified_mandates'].value_counts(dropna=False).head(10)
# Out:
# False    11187
# True        64
# Name: verified_mandates, dtype: int64

# %% [markdown]
# #### Attribution

# %%
closed_opps_df['attribution_touchpoint_count'].value_counts(dropna=False).head(10)
# Out:
# NaN      3852
# 3.000    1173
# 4.000    1090
# 2.000     896
# 5.000     707
# 6.000     578
# 1.000     520
# 7.000     401
# 8.000     290
# 9.000     263
# Name: attribution_touchpoint_count, dtype: int64

# %%
closed_opps_df['attribution_touchpoint_count'][closed_opps_df['attribution_touchpoint_count'] < 20].hist(bins=10);

# %%
closed_opps_df['sales_attribution_touchpoint_count'].value_counts(dropna=False).head(10)
# Out:
# 0.000    6836
# NaN      3852
# 1.000     436
# 2.000     105
# 3.000      17
# 4.000       4
# 5.000       1
# Name: sales_attribution_touchpoint_count, dtype: int64

# %%
closed_opps_df['marketing_attribution_touchpoint_count'].value_counts(dropna=False).head(10)
# Out:
# NaN      3852
# 3.000    1169
# 4.000    1092
# 2.000     939
# 5.000     705
# 6.000     566
# 1.000     540
# 7.000     385
# 8.000     283
# 9.000     261
# Name: marketing_attribution_touchpoint_count, dtype: int64

# %% [markdown]
# #### cm_instant_bank_pay
#
# - What is this?

# %%
closed_opps_df['cm_instant_bank_pay'].value_counts(dropna=False).head(10)
# Out:
# NaN                                              10889
# Remove Instant Bank Pay (if already selected)      187
# Instant Bank Pay                                   175
# Name: cm_instant_bank_pay, dtype: int64

# %% [markdown]
# #### cm_add_success_plus
#
# - What is this?

# %%
closed_opps_df['cm_add_success_plus'].value_counts(dropna=False).head(10)
# Out:
# NaN                                          10948
# Remove Success Plus (if already selected)      204
# Add Success Plus                                99
# Name: cm_add_success_plus, dtype: int64

# %%
closed_opps_df['current_dd_provider'].value_counts(dropna=False).head(10)
# Out:
# NaN           9185
# Bank           200
# GoCardless     186
# Bottomline      68
# GC              67
# None            39
# Barclays        37
# HSBC            36
# Natwest         32
# bank            32
# Name: current_dd_provider, dtype: int64

# %% [markdown]
# #### closed_lost_detail

# %%
closed_opps_df['closed_lost_detail'].head(10)
# Out:
# 6032                                                  NaN
# 6033                                                  NaN
# 6034                                                  NaN
# 6035                                                  NaN
# 6036                               No engagement from CFO
# 6037                                                  NaN
# 6038    Getting free trx volumes from braintree and pa...
# 6039                                                  NaN
# 6041                                                  NaN
# 6042                                                  NaN
# Name: closed_lost_detail, dtype: object

# %%
closed_opps_df['closed_lost_detail'].isna().sum() / closed_opps_df.shape[0]
# Out:
# 0.539266439035136

# %% [markdown]
# #### max_stage_reached

# %%
closed_opps_df['max_stage_reached'].value_counts(dropna=False)
# Out:
# 7. Closed Won       4208
# 1. Discover         2600
# 3. Collaborate       531
# NaN                  489
# 2. Qualify           471
# 5. Negotiation       419
# 4. Confirm           244
# 6. Signature          76
# 0. SDR Qualified      41
# Name: max_stage_reached, dtype: int64

# %% [markdown]
# #### opportunity_owner_growth_engine

# %%
closed_opps_df['opportunity_owner_growth_engine'].value_counts(dropna=False)
# Out:
# NaN               3156
# Corporate         2591
# Emerging          2543
# Enterprise         517
# Small Business     268
# GE Wide              4
# Name: opportunity_owner_growth_engine, dtype: int64

# %% [markdown]
# #### existing_payment_options

# %%
closed_opps_df[(closed_opps_df['existing_payment_options'].isna()) | (closed_opps_df['existing_payment_options'] == 'None')].shape[0] / closed_opps_df.shape[0]
# Out:
# 0.6155964313250358

# %%
closed_opps_df['existing_payment_options'].value_counts().head()
# Out:
# Direct Debit - FM    840
# Bank Transfer        375
# None                 311
# Direct Debit - MA    291
# Credit Cards         209
# Name: existing_payment_options, dtype: int64

# %%
closed_opps_df[~closed_opps_df['existing_payment_options'].isna()][['existing_payment_options']].head()
# Out:
#       existing_payment_options
# 6034             Bank Transfer
# 6037         Direct Debit - FM
# 6038  Credit Cards;Debit Cards
# 6039         Direct Debit - MA
# 6041                      None

# %% [markdown]
# #### current_dd_provider

# %%
closed_opps_df['current_dd_provider'].value_counts(dropna=False)
# Out:
# NaN                                    7307
# Bank                                    170
# GoCardless                              167
# GC                                       64
# Bottomline                               57
#                                        ...
# AIB bank                                  1
# HSBC - through Bottomline                 1
# Faster Pay                                1
# Bottomline ptx, Handelsbanken, HSBC       1
# Adyen for SEPA                            1
# Name: current_dd_provider, Length: 616, dtype: int64

# %% [markdown]
# ### Dates

# %%
def agg_plot_weekly(x):
    x = pd.to_datetime(x)
    x = x.dt.date
    x = x.value_counts()
    x.index = pd.to_datetime(x.index)
    x.resample('W').sum().plot();

# %%
agg_plot_weekly(closed_opps_df['opportunity_created_date'])

# %%
agg_plot_weekly(closed_opps_df['opportunity_contract_signed_date'])

# %%
agg_plot_weekly(closed_opps_df['opportunity_closed_lost_date'])

# %%
# Conversion rate by month
closed_opps_df['opportunity_created_date'] = pd.to_datetime(closed_opps_df['opportunity_created_date'])
closed_opps_df['MONTH_YEAR'] = closed_opps_df['opportunity_created_date'].to_numpy().astype('datetime64[M]')
# Out:
# /var/folders/vq/hlvrqms16b70m_gc56_xm3040000gn/T/ipykernel_99302/661735948.py:3: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   closed_opps_df['MONTH_YEAR'] = closed_opps_df['opportunity_created_date'].to_numpy().astype('datetime64[M]')

# %%
# Plot
ax = closed_opps_df.groupby('MONTH_YEAR')['closed_won'].mean().resample("M").sum().plot(title='Conversion rate by month', color="#272635", figsize=(10,5))
ax.set_ylabel("Conversion Rate")
ax.set_xlabel("Month")
plt.show();

# %% [markdown]
# ### Crosstabs

# %%
closed_opps_df['closed_won'] = np.where(closed_opps_df['opportunity_stage_name'] == '7. Closed Won', 1, 0)

# %%
target = 'closed_won'
features = ['country', 'vertical', 'annual_revenue_db']

# %%
# Overall mean
closed_opps_df[target].mean()
# Out:
# 0.42618433916985154

# %%
# Top 5 markets
closed_opps_df['country'].value_counts()[:5]
# Out:
# United Kingdom    7853
# France            1272
# Germany            639
# Australia          426
# United States      376
# Name: country, dtype: int64

# %%
closed_opps_df['country5'] = [i if i in closed_opps_df['country'].value_counts()[:5].index else 'other' for i in closed_opps_df['country']]

# %%
# Mean by country
closed_opps_df.groupby('country5')[target].agg(['mean', 'size']).sort_values(by='mean', ascending=False)
# Out:
#                 mean  size
# country5
# United Kingdom 0.466  7853
# France         0.384  1272
# other          0.378   685
# Germany        0.316   639
# Australia      0.282   426
# United States  0.170   376

# %%
# Mean by vertical
closed_opps_df.groupby('vertical')[target].agg(['mean', 'size']).sort_values(by='mean', ascending=False)
# Out:
#                                 mean  size
# vertical
# Transportation                 0.573   234
# Amusement and Recreation       0.550   120
# Services                       0.521  1536
# Education and Training         0.468   340
# Nonclassifiable Establishments 0.458   262
# Membership Organisations       0.450   342
# Materials                      0.442    43
# Communications and Media       0.439   875
# Property                       0.438   363
# Consumer Goods                 0.429   777
# Health and Wellbeing           0.419   499
# NGO                            0.408   157
# Financial Services             0.397  1278
# Government                     0.389   211
# Industrials                    0.376    85
# Information Technology         0.375  1947
# Energy                         0.373   322
# Travel                         0.338    74
# Insurance                      0.337   255
# Gambling                       0.000     3

# %%
# Revenue
closed_opps_df['annual_revenue_db'].hist();

# %%
closed_opps_df = closed_opps_df[(closed_opps_df['annual_revenue_db'] < 1e8) & (closed_opps_df['annual_revenue_db'] > 0)]

# %%
closed_opps_df.shape
# Out:
# (9079, 244)

# %%
closed_opps_df['annual_revenue_db'].hist();

# %%
closed_opps_df['revenue_bins'] = pd.cut(closed_opps_df['annual_revenue_db'], bins=10)

# %%
closed_opps_df['revenue_bins'].value_counts()
# Out:
# (-98143.406, 9814643.6]     6941
# (19629284.2, 29443924.8]    1452
# (68702487.2, 78517127.8]     281
# (9814643.6, 19629284.2]      224
# (29443924.8, 39258565.4]      68
# (39258565.4, 49073206.0]      39
# (49073206.0, 58887846.6]      28
# (58887846.6, 68702487.2]      23
# (78517127.8, 88331768.4]      17
# (88331768.4, 98146409.0]       6
# Name: revenue_bins, dtype: int64
